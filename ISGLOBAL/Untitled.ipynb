# %%
import pandas as pd

# %%
df=pd.read_excel("CUALIT.XLSX")

# %%
df
# Out:
#     Nro       Region                                          CS  \
# 0     1  Villa Hayes                                 USF BOUVIER
# 1     2  Villa Hayes                            USF CIUDAD NUEVA
# 2     3  Villa Hayes                                 USF MEMONG
# 3     4  Villa Hayes               USF SAN JORGE DE VILLA HAYES
# 4     5  Villa Hayes                            USF PA´I ROBERTO
# 5     6  Villa Hayes                   PUESTO DE SALUD REMANSITO
# 6     7  Coordillera                 HOSPITAL DISTRITAL DE ALTOS
# 7     8  Coordillera                        USF TUCANGUÁ - ALTOS
# 8     9  Coordillera                         USF ITAGAZA - ALTOS
# 9    10  Coordillera                        USF ZANJA HÚ - ATYRA
# 10   11  Coordillera                    CENTRO DE SALUD DE ATYRÁ
# 11   12  Coordillera                          USF CORONEL DUARTE
# 12   13  Coordillera                HOSPITAL REGIONAL DE CAACUPÉ
# ...

# %%
df.columns
# Out:
# Index(['Nro', 'Region', 'CS', 'Nombre',
#        '¿Les fueron de utilidad los materiales de comunicación?',
#        '¿Considera qué hay algún impacto en los pacientes/comunidad? ¿Cuál? ',
#        '¿Si pudiera hacer algún cambio lo haría?'],
#       dtype='object')

# %%
import pandas as pd
from textblob import TextBlob

# %%
df['texto'] = df['¿Si pudiera hacer algún cambio lo haría?'].str.lower().replace('[^a-zA-Z0-9ñáéíóúü]', ' ', regex=True)

# %%
df['sentimiento'] = df['texto'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
df.head(5)
# Out:
#    Nro       Region                             CS  \
# 0    1  Villa Hayes                    USF BOUVIER
# 1    2  Villa Hayes               USF CIUDAD NUEVA
# 2    3  Villa Hayes                    USF MEMONG
# 3    4  Villa Hayes  USF SAN JORGE DE VILLA HAYES
# 4    5  Villa Hayes               USF PA´I ROBERTO
#
#                                  Nombre  \
# 0                 Lic. Esther Castilllo
# 1                   Lic. Nelly Martínez
# 2                     Dr. Diego Ramírez
# 3                      Lic. Rocío Muñoz
# 4  Agente Comunitaria, Sandra Melgarejo
#
#   ¿Les fueron de utilidad los materiales de comunicación?  \
# 0                          Nos fue de mucha utilidad
# 1  Los materiales son de gran utilidad porque ayu...
# 2  Son de mucha utilidad los materiales de comuni...
# 3                      Los materiales son muy útiles
# 4                                                 Si
#
#   ¿Considera qué hay algún impacto en los pacientes/comunidad? ¿Cuál?   \
# ...
