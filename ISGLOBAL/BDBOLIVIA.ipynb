# %% [markdown]
# ##### IMPORTAR LIBRERIAS Y LEER LOS DATOS

# %%
import pandas as pd

# %%
df1=pd.read_excel("CBBA_ECO_FICHAS.XLSX")
# Out:
# C:\Users\l_vil\AppData\Local\Temp\ipykernel_26472\3331332125.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df1=pd.read_excel("CBBA_ECO_FICHAS.XLSX")

# %%
df1.head()
# Out:
#    Unnamed: 0 FECHA NOTIFICACIÓN  SEMANA EPIDEMIOLÓGICA  \
# 0           0         2020-03-26                     13
# 1           1         2020-03-26                     13
# 2           2         2020-03-26                     13
# 3           3         2020-03-27                     13
# 4           4         2020-03-30                     14
#
#                           ESTABLECIMIENTO NÚMERO DE DOCUMENTO(CI/PASAPORTE)  \
# 0       HOSPITAL DEL SUD - COCHABAMBA/CBA                           6457430
# 1  C.S. MINEROS SAN JUAN - COCHABAMBA/CBA                           8708091
# 2                 ALALAY - COCHABAMBA/CBA                           3606838
# 3                 ALALAY - COCHABAMBA/CBA                               NaN
# 4                 ALALAY - COCHABAMBA/CBA                               NaN
#
#   FECHA DE NACIMIENTO  EDAD       SEXO FECHA INICIO SINTOMAS    AMB./INT.  \
# 0          1986-02-12  36.0  MASCULINO                   NaT          NaN
# ...

# %%
df1.shape
# Out:
# (128321, 52)

# %%
df2=pd.read_excel("CBBA_ECO_LABS.XLSX")

# %%
df2.head()
# Out:
#    Unnamed: 0                                        Laboratorio SubSector  \
# 0           1  LABORATORIO DEPARTAMENTAL DE REFERENCIA(COCHAB...   PUBLICO
# 1           2                 LAB. HOSPITAL DEL SUD (COCHABAMBA)   PUBLICO
# 2           3         LAB. C.S. SEBASTIAN PAGADOR (CERCADO/CBBA)   PUBLICO
# 3           4                    LAB. C.S. ALALAY (CERCADO/CBBA)   PUBLICO
# 4           5                      LAB. KARA KARA (CERCADO/CBBA)   PUBLICO
#
#    Gestor   Fecha de Recepción Código Laboratorio Muestra de Control Sí/No  \
# 0     NaN  2020-08-03 00:00:00              15942                       NO
# 1     NaN  2021-04-05 00:00:00                248                       NO
# 2     NaN                  NaN                NaN                       NO
# 3     NaN                  NaN                NaN                       NO
# 4     NaN  2021-05-17 00:00:00                NaN                       NO
#
# ...

# %%
df2.shape
# Out:
# (123987, 25)

# %% [markdown]
# ##### ELIMINACION DE DUPLICADOS

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'FECHA NOTIFICACIÓN', 'SEMANA EPIDEMIOLÓGICA',
#        'ESTABLECIMIENTO', 'NÚMERO DE DOCUMENTO(CI/PASAPORTE)',
#        'FECHA DE NACIMIENTO', 'EDAD', 'SEXO', 'FECHA INICIO SINTOMAS',
#        'AMB./INT.', 'FECHA INTERNACIÓN', 'FECHA AISLAMIENTO',
#        'LUGAR AISLAMIENTO', 'ESTABLECIMIENTO DE SALUD DE INTERNACIÓN',
#        'TERAPIA INTENSIVA', 'FECHA INGRESO UTI.', 'VENTILACIÓN MECÁNICA',
#        ''ASINTOMÁTICO'', 'Sinto/Asint', 'TOS SECA', 'DOLOR DE GARGANTA',
#        'FIEBRE', 'DIFICULTAD RESPIRATORIA', 'MIALGIAS', 'MALESTAR GENERAL',
#        'CEFALEA', 'PÉRDIDA Y / O DISMINUCIÓN DEL OLFATO',
#        'PÉRDIDA Y / O DISMINUCIÓN DEL GUSTO', 'OTRO SÍNTOMA', 'OTRO SINTOMA',
#        'Enfermedad de base', 'DIABETES', 'OBESIDAD',
#        'ENFERMEDAD RENAL CRÓNICA', 'EMBARAZO', 'HIPERTENSIÓN ARTERIAL',
#        'ENFERMEDAD CARDÍACA', 'ENFERMEDAD ONCOLÓGICA',
#        'ENFERMEDAD RESPIRATORIA', 'OTROS', 'OTRA ENFERMEDAD', 'ESTADO',
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Laboratorio', 'SubSector', 'Gestor',
#        'Fecha de Recepción', 'Código Laboratorio', 'Muestra de Control Sí/No',
#        'Establecimiento de Salud', 'Municipio', 'Departamento',
#        'Cód. Establecimiento', 'Número documento', 'Sexo', 'Edad',
#        'Edad en unidad de tiempo', 'Teléfono / Cel', 'Direccion',
#        'Fecha de Inicio de síntomas', 'Fecha de Notificación',
#        'Fecha de toma de muestra', 'Tipo de muestra',
#        'Fecha de reporte / resultado', 'Resultado Laboratorio',
#        'Observaciones del resultado', 'Método de diagnóstico'],
#       dtype='object')

# %%
df1a=df1.drop_duplicates(subset=["NÚMERO DE DOCUMENTO(CI/PASAPORTE)"], keep='first', inplace=False)
