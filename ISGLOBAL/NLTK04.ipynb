# %%
import pandas as pd

# %%
df=pd.read_excel("CUALIT.XLSX")

# %%
df.head(3)
# Out:
#    Nro       Region                CS                 Nombre  \
# 0    1  Villa Hayes       USF BOUVIER  Lic. Esther Castilllo
# 1    2  Villa Hayes  USF CIUDAD NUEVA    Lic. Nelly Martínez
# 2    3  Villa Hayes       USF MEMONG       Dr. Diego Ramírez
#
#   ¿Les fueron de utilidad los materiales de comunicación?  \
# 0                          Nos fue de mucha utilidad
# 1  Los materiales son de gran utilidad porque ayu...
# 2  Son de mucha utilidad los materiales de comuni...
#
#   ¿Considera qué hay algún impacto en los pacientes/comunidad? ¿Cuál?   \
# 0  Si porque a pesar de que algunas personas ya n...
# 1  Si. Consulta oportuna para tratamiento precoz,...
# 2  Considero que existe algún impacto en los paci...
#
#             ¿Si pudiera hacer algún cambio lo haría?
# 0  No porque las personas que acuden al servicio ...
# 1  Sí. implementar cero papel y cambiar la inform...
# 2  Por el momento los materiales de comunicación ...

# %%
df.columns
# Out:
# Index(['Nro', 'Region', 'CS', 'Nombre',
#        '¿Les fueron de utilidad los materiales de comunicación?',
#        '¿Considera qué hay algún impacto en los pacientes/comunidad? ¿Cuál? ',
#        '¿Si pudiera hacer algún cambio lo haría?'],
#       dtype='object')

# %%
from textblob import TextBlob

# %%
texto = df['¿Les fueron de utilidad los materiales de comunicación?']

# %%
# Crear objeto TextBlob con idioma español
# Out:
# 0                             Nos fue de mucha utilidad
# 1     Los materiales son de gran utilidad porque ayu...
# 2     Son de mucha utilidad los materiales de comuni...
# 3     Los materiales son muy útiles, llaman la atenc...
# 4      Fue muy útil. Los pacientes prestan más atención
# 5                                 Si fueron de utilidad
# 6                                  Si de mucha utilidad
# 7             Muy útil, utilizamos todos los materiales
# 8     Es de utilidad porque sirve de material de apo...
# 9               Fueron de mucha utilidad los materiales
# 10    Si, ya que con estos materiales se pudo inform...
# 11    Los materiales son muy útiles y nos facilita b...
# 12                        Nos fue de muchísima utilidad
# 13    Los materiales fueron de mucha ayuda para pode...
# 14    Los materiales de comunicación me fueron, me s...
# 15    Los materiales son muy útiles para nuestra com...
# 16    Los materiales fueron de mucha utilidad. Ayuda...
# ...

# %%
df['sentimiento'] = texto.apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
df
# Out:
#     Nro       Region                                          CS  \
# 0     1  Villa Hayes                                 USF BOUVIER
# 1     2  Villa Hayes                            USF CIUDAD NUEVA
# 2     3  Villa Hayes                                 USF MEMONG
# 3     4  Villa Hayes               USF SAN JORGE DE VILLA HAYES
# 4     5  Coordillera                 HOSPITAL DISTRITAL DE ALTOS
# 5     6  Coordillera                        USF TUCANGUÁ - ALTOS
# 6     7  Coordillera                         USF ITAGAZA - ALTOS
# 7     8  Coordillera                        USF ZANJA HÚ - ATYRA
# 8     9  Coordillera                    CENTRO DE SALUD DE ATYRÁ
# 9    10  Coordillera                HOSPITAL REGIONAL DE CAACUPÉ
# 10   11  Coordillera             REGIÓN SANITARIA DE CORDILLERA
# 11   12  Coordillera                  USF AQUINO CAÑADA, CAACUPÉ
# 12   13  Coordillera                      USF CABAÑAS 1, CAACUPE
# ...
