# %%
import pandas as pd
import numpy as nu
import scipy as sc
import matplotlib.pyplot as plt

# %%
datos=pd.read_spss ('D:/GESTIONES/GESTION 2021/CURSOS/UMSS/MEDICINA/BASES DE DATOS/1. HEALTH.SAV')

# %%
datos.head()
# Out:
#      PG01  PG02  PG03   PG04  PG05  PG06   PG07  PG08   PG09  PG10  PG11  \
# 0   Mujer  19.0  64.8  105.4  72.9  76.0  112.0  62.0   44.0  17.7  39.1
# 1   Mujer  23.0  64.7  108.8  74.5  72.0   98.0  61.0   62.0  18.3  43.4
# 2   Mujer  24.0  62.6  106.7  70.0  76.0  106.0  59.0  237.0  19.2  38.1
# 3   Mujer  40.0  58.6   94.3  67.8  80.0  118.0  82.0   94.0  19.3  32.1
# 4  Hombre  36.0  70.3  137.1  81.6  64.0  112.0  77.0  176.0  19.6  40.8
#
#    PG12  PG13  PG14        CPG10
# 0   5.7   4.8  23.7  17,6 - 23,0
# 1   6.2   5.2  24.7  17,6 - 23,0
# 2   6.1   5.0  23.6  17,6 - 23,0
# 3   5.4   4.2  23.3  17,6 - 23,0
# 4   7.1   5.3  27.9  17,6 - 23,0

# %%
datos['PG01'].count()
# Out:
# 80

# %%
datos[['PG02', 'PG03','PG04' ]].corr()
# Out:
#           PG02      PG03      PG04
# PG02  1.000000  0.214419  0.428472
# PG03  0.214419  1.000000  0.544563
# PG04  0.428472  0.544563  1.000000

# %%
datos.boxplot(column="PG02", by="PG01", figsize=(8,6))
plt.show()

# %%
dir(datos)
# Out:
# ['CPG10',
#  'PG01',
#  'PG02',
#  'PG03',
#  'PG04',
#  'PG05',
#  'PG06',
#  'PG07',
#  'PG08',
#  'PG09',
#  'PG10',
#  'PG11',
#  'PG12',
#  'PG13',
#  'PG14',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
# ...

# %%
s_datos=datos.sample(5)

# %%
print (s_datos)
# Out:
#       PG01  PG02  PG03   PG04  PG05  PG06   PG07  PG08   PG09  PG10  PG11  \
# 46  Hombre  20.0  68.3  175.2  89.1  76.0  137.0  85.0  121.0  26.4  42.1
# 12   Mujer  29.0  68.0  135.5  75.9  88.0  119.0  81.0  271.0  20.7  39.0
# 14   Mujer  29.0  63.6  123.1  75.4  68.0  101.0  66.0   62.0  21.4  43.2
# 3    Mujer  40.0  58.6   94.3  67.8  80.0  118.0  82.0   94.0  19.3  32.1
# 42   Mujer  34.0  60.5  135.0  85.7  60.0  125.0  73.0  149.0  26.0  39.9
#
#     PG12  PG13  PG14        CPG10
# 46   7.5   5.5  32.0  23,1 - 28,5
# 12   6.3   4.9  27.8  17,6 - 23,0
# 14   6.0   4.9  26.4  17,6 - 23,0
# 3    5.4   4.2  23.3  17,6 - 23,0
# 42   6.4   5.2  30.9  23,1 - 28,5

# %%
datos_sexo=datos.groupby(['PG01'])

# %%
datos_sexo.mean()
# Out:
#           PG02    PG03    PG04     PG05  PG06   PG07    PG08     PG09  \
# PG01
# Hombre  35.475  68.335  172.55  91.2850  69.4  118.9  73.225  395.225
# Mujer   33.225  63.195  146.22  85.0325  76.3  110.8  67.425  240.875
#
#            PG10     PG11   PG12    PG13     PG14
# PG01
# Hombre  25.9975  42.5725  7.295  5.8000  32.3875
# Mujer   25.7400  38.8625  6.375  5.0675  30.1575

# %%
datos.head()
# Out:
#      PG01  PG02  PG03   PG04  PG05  PG06   PG07  PG08   PG09  PG10  PG11  \
# 0   Mujer  19.0  64.8  105.4  72.9  76.0  112.0  62.0   44.0  17.7  39.1
# 1   Mujer  23.0  64.7  108.8  74.5  72.0   98.0  61.0   62.0  18.3  43.4
# 2   Mujer  24.0  62.6  106.7  70.0  76.0  106.0  59.0  237.0  19.2  38.1
# 3   Mujer  40.0  58.6   94.3  67.8  80.0  118.0  82.0   94.0  19.3  32.1
# 4  Hombre  36.0  70.3  137.1  81.6  64.0  112.0  77.0  176.0  19.6  40.8
#
#    PG12  PG13  PG14        CPG10
# 0   5.7   4.8  23.7  17,6 - 23,0
# 1   6.2   5.2  24.7  17,6 - 23,0
# 2   6.1   5.0  23.6  17,6 - 23,0
# 3   5.4   4.2  23.3  17,6 - 23,0
# 4   7.1   5.3  27.9  17,6 - 23,0

# %%
datos_mujer=datos[datos['PG01']=='Mujer']

# %%
datos_mujer.shape
# Out:
# (40, 15)

# %%
datos_hombre=datos[datos['PG01']=='Hombre']

# %%
datos_hombre.shape
# Out:
# (40, 15)
